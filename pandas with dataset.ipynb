# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
print(os.listdir())
# Out:
# ['.anaconda', '.conda', '.condarc', '.continuum', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.opera', '10N.py.ipynb', '11Jn.ipynb', '11N.ipynb', '12Jn.ipynb', '12N.py.ipynb', '13Jn.ipynb', '14N.py.ipynb', '15N.ipynb', '16N.ipynb', '17N.ipynb', '18N.ipynb', '2', '21N.ipynb', '22N.ipynb', '23N.ipynb', '3D Objects', '7NOV.py.ipynb', '9Nov.ipynb', 'Ada-Boost Implementation.ipynb', 'anaconda3', 'AppData', 'apple.csv', 'Application Data', 'Autoregression using ACF and PACP explained.ipynb', 'Basic practice .ipynb', 'Basic practice session.ipynb', 'Basic python program.ipynb', 'Boston.csv', 'california housing test.csv', 'california housing train.csv', 'car evaluation.csv', 'CatBoost Vs XGBoost Vs LightGBM - Part 1.ipynb', 'Classification Data.csv', 'Cleaning Text Data.ipynb', 'CLTV leading insurance company train BRCpofr.csv', 'CLTV sample_submission.csv', 'CLTV test_koRSKBP.csv', 'Contacts', 'Cookies', 'COVID-19 India Satewise data.csv', 'COVID-19 Positive patients Data
# ...

# %%
df=pd.read_csv('Mall_Customers.csv')

# %%
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.isnull()
# Out:
#      CustomerID  Genre    Age  Annual Income (k$)  Spending Score (1-100)
# 0         False  False  False               False                   False
# 1         False  False  False               False                   False
# 2         False  False  False               False                   False
# 3         False  False  False               False                   False
# 4         False  False  False               False                   False
# ..          ...    ...    ...                 ...                     ...
# 195       False  False  False               False                   False
# 196       False  False  False               False                   False
# 197       False  False  False               False                   False
# 198       False  False  False               False                   False
# 199       False  False  False               False                   False
#
# [200 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
missing_values=["N/a","na",np.nan]
df=pd.read_csv('Mall_Customers.csv',na_values=missing_values)

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.isnull().any()
# Out:
# CustomerID                False
# Genre                     False
# Age                       False
# Annual Income (k$)        False
# Spending Score (1-100)    False
# dtype: bool

# %%
sns.heatmap(df.isnull(),yticklabels=False,annot=True)
# Out:
# <AxesSubplot:>

# %%
df.dropna(how='all')
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.interpolate()
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
df.astype
# Out:
# <bound method NDFrame.astype of      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]>

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.tail()
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
df.shape
# Out:
# (200, 5)

# %%
df.dtypes
# Out:
# CustomerID                 int64
# Genre                     object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %%
df.isna().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.sort_values('CustomerID').tail()
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
df.sort_values('CustomerID').head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.sort_values('Annual Income (k$)').head(10)
# Out:
#     CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0            1    Male   19                  15                      39
# 1            2    Male   21                  15                      81
# 2            3  Female   20                  16                       6
# 3            4  Female   23                  16                      77
# 4            5  Female   31                  17                      40
# 5            6  Female   22                  17                      76
# 6            7  Female   35                  18                       6
# 7            8  Female   23                  18                      94
# 11          12  Female   35                  19                      99
# 10          11    Male   67                  19                      14

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.CustomerID.plot()
# Out:
# <AxesSubplot:>

# %%
df.CustomerID.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df.to_numpy()
# Out:
# array([[1, 'Male', 19, 15, 39],
#        [2, 'Male', 21, 15, 81],
#        [3, 'Female', 20, 16, 6],
#        [4, 'Female', 23, 16, 77],
#        [5, 'Female', 31, 17, 40],
#        [6, 'Female', 22, 17, 76],
#        [7, 'Female', 35, 18, 6],
#        [8, 'Female', 23, 18, 94],
#        [9, 'Male', 64, 19, 3],
#        [10, 'Female', 30, 19, 72],
#        [11, 'Male', 67, 19, 14],
#        [12, 'Female', 35, 19, 99],
#        [13, 'Female', 58, 20, 15],
#        [14, 'Female', 24, 20, 77],
#        [15, 'Male', 37, 20, 13],
#        [16, 'Male', 22, 20, 79],
#        [17, 'Female', 35, 21, 35],
#        [18, 'Male', 20, 21, 66],
#        [19, 'Male', 52, 23, 29],
#        [20, 'Female', 35, 23, 98],
#        [21, 'Male', 35, 24, 35],
#        [22, 'Male', 25, 24, 73],
#        [23, 'Female', 46, 25, 5],
#        [24, 'Male', 31, 25, 73],
#        [25, 'Female', 54, 28, 14],
#        [26, 'Male', 29, 28, 82],
#        [27, 'Female', 45, 28, 32],
#        [28, 'Male', 35, 28, 61],
# ...

# %%
df.corr()
# Out:
#                         CustomerID       Age  Annual Income (k$)  \
# CustomerID                1.000000 -0.026763            0.977548
# Age                      -0.026763  1.000000           -0.012398
# Annual Income (k$)        0.977548 -0.012398            1.000000
# Spending Score (1-100)    0.013835 -0.327227            0.009903
#
#                         Spending Score (1-100)
# CustomerID                            0.013835
# Age                                  -0.327227
# Annual Income (k$)                    0.009903
# Spending Score (1-100)                1.000000

# %%
df.max()
# Out:
# CustomerID                 200
# Genre                     Male
# Age                         70
# Annual Income (k$)         137
# Spending Score (1-100)      99
# dtype: object

# %%
df.min()
# Out:
# CustomerID                     1
# Genre                     Female
# Age                           18
# Annual Income (k$)            15
# Spending Score (1-100)         1
# dtype: object

# %%
df.mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_19416\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# CustomerID                100.50
# Age                        38.85
# Annual Income (k$)         60.56
# Spending Score (1-100)     50.20
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_19416\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# CustomerID                100.5
# Age                        36.0
# Annual Income (k$)         61.5
# Spending Score (1-100)     50.0
# dtype: float64

# %%
df.mode()
# Out:
#      CustomerID   Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1  Female  32.0                54.0                    42.0
# 1             2     NaN   NaN                78.0                     NaN
# 2             3     NaN   NaN                 NaN                     NaN
# 3             4     NaN   NaN                 NaN                     NaN
# 4             5     NaN   NaN                 NaN                     NaN
# ..          ...     ...   ...                 ...                     ...
# 195         196     NaN   NaN                 NaN                     NaN
# 196         197     NaN   NaN                 NaN                     NaN
# 197         198     NaN   NaN                 NaN                     NaN
# 198         199     NaN   NaN                 NaN                     NaN
# 199         200     NaN   NaN                 NaN                     NaN
#
# [200 rows x 5 columns]

# %%
df1=df[['CustomerID','Annual Income (k$)']]
df1
# Out:
#      CustomerID  Annual Income (k$)
# 0             1                  15
# 1             2                  15
# 2             3                  16
# 3             4                  16
# 4             5                  17
# ..          ...                 ...
# 195         196                 120
# 196         197                 126
# 197         198                 126
# 198         199                 137
# 199         200                 137
#
# [200 rows x 2 columns]

# %%
df['Annual Income (k$)'] >15
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 195     True
# 196     True
# 197     True
# 198     True
# 199     True
# Name: Annual Income (k$), Length: 200, dtype: bool

# %%
df.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.loc[0,:]
# Out:
# CustomerID                   1
# Genre                     Male
# Age                         19
# Annual Income (k$)          15
# Spending Score (1-100)      39
# Name: 0, dtype: object

# %%
df.loc[[0,1,2],:]
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6

# %%
df.loc[0:2,:]
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6

# %%
df.loc[:,['CustomerID','Annual Income (k$)']]
# Out:
#      CustomerID  Annual Income (k$)
# 0             1                  15
# 1             2                  15
# 2             3                  16
# 3             4                  16
# 4             5                  17
# ..          ...                 ...
# 195         196                 120
# 196         197                 126
# 197         198                 126
# 198         199                 137
# 199         200                 137
#
# [200 rows x 2 columns]

# %%
df.loc[0:3,'Age':'Spending Score (1-100)']
# Out:
#    Age  Annual Income (k$)  Spending Score (1-100)
# 0   19                  15                      39
# 1   21                  15                      81
# 2   20                  16                       6
# 3   23                  16                      77

# %%
df.head(3).drop('Spending Score (1-100)',axis=1)
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)
# 0           1    Male   19                  15
# 1           2    Male   21                  15
# 2           3  Female   20                  16

# %%
df[df.Genre=='Male']
# Out:
#      CustomerID Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1  Male   19                  15                      39
# 1             2  Male   21                  15                      81
# 8             9  Male   64                  19                       3
# 10           11  Male   67                  19                      14
# 14           15  Male   37                  20                      13
# ..          ...   ...  ...                 ...                     ...
# 187         188  Male   28                 101                      68
# 192         193  Male   33                 113                       8
# 197         198  Male   32                 126                      74
# 198         199  Male   32                 137                      18
# 199         200  Male   30                 137                      83
#
# [88 rows x 5 columns]

# %%
df.loc[df.Genre=='Male',:]
# Out:
#      CustomerID Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1  Male   19                  15                      39
# 1             2  Male   21                  15                      81
# 8             9  Male   64                  19                       3
# 10           11  Male   67                  19                      14
# 14           15  Male   37                  20                      13
# ..          ...   ...  ...                 ...                     ...
# 187         188  Male   28                 101                      68
# 192         193  Male   33                 113                       8
# 197         198  Male   32                 126                      74
# 198         199  Male   32                 137                      18
# 199         200  Male   30                 137                      83
#
# [88 rows x 5 columns]

# %%
df.loc[df.Genre=='Male','CustomerID']
# Out:
# 0        1
# 1        2
# 8        9
# 10      11
# 14      15
#       ...
# 187    188
# 192    193
# 197    198
# 198    199
# 199    200
# Name: CustomerID, Length: 88, dtype: int64

# %%
df[df.Genre=='Male'].CustomerID
# Out:
# 0        1
# 1        2
# 8        9
# 10      11
# 14      15
#       ...
# 187    188
# 192    193
# 197    198
# 198    199
# 199    200
# Name: CustomerID, Length: 88, dtype: int64

# %%
df.iloc[:,[0,3]]
# Out:
#      CustomerID  Annual Income (k$)
# 0             1                  15
# 1             2                  15
# 2             3                  16
# 3             4                  16
# 4             5                  17
# ..          ...                 ...
# 195         196                 120
# 196         197                 126
# 197         198                 126
# 198         199                 137
# 199         200                 137
#
# [200 rows x 2 columns]

# %%
df.iloc[:,0:2]
# Out:
#      CustomerID   Genre
# 0             1    Male
# 1             2    Male
# 2             3  Female
# 3             4  Female
# 4             5  Female
# ..          ...     ...
# 195         196  Female
# 196         197  Female
# 197         198    Male
# 198         199    Male
# 199         200    Male
#
# [200 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
df.iloc[0:2,:]
# Out:
#    CustomerID Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1  Male   19                  15                      39
# 1           2  Male   21                  15                      81

# %%
df.loc[:,['CustomerID','Annual Income (k$)']]
# Out:
#      CustomerID  Annual Income (k$)
# 0             1                  15
# 1             2                  15
# 2             3                  16
# 3             4                  16
# 4             5                  17
# ..          ...                 ...
# 195         196                 120
# 196         197                 126
# 197         198                 126
# 198         199                 137
# 199         200                 137
#
# [200 rows x 2 columns]

# %%
df[0:2]
# Out:
#    CustomerID Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1  Male   19                  15                      39
# 1           2  Male   21                  15                      81

# %%
df.iloc[0:2,:]
# Out:
#    CustomerID Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1  Male   19                  15                      39
# 1           2  Male   21                  15                      81

# %%
drinks=pd.read_csv('drinksbycountry.csv')

# %%
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
 drinks.iloc[4,1]
# Out:
# 217

# %%
# !pip install pandas

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
drinks.rename(columns={"country": "COUNTRY"}, inplace=True)
drinks
# Out:
#          COUNTRY  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
drinks.rename(columns={"COUNTRY": "Country", "beer_servings": "Beer_Servings", "spirit_servings": "Spirit_servings",
                        "wine_servings":"Wine_servings","total_litres_of_pure_alcohol":"PureAlcoholInLitre",
                         "continent":"Continent"}, inplace=True,)
drinks
# Out:
#          Country  Beer_Servings  Spirit_servings  Wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      PureAlcoholInLitre      Continent
# 0                   0.0           Asia
# 1                   4.9         Europe
# 2                   0.7         Africa
# ...

# %%
country=pd.read_csv("population_by_country.csv")

# %%
country
# Out:
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                     China         1440297825        0.39 %     5540090
# 1                     India         1382345085        0.99 %    13586631
# 2             United States          331341050        0.59 %     1937734
# 3                 Indonesia          274021604        1.07 %     2898047
# 4                  Pakistan          221612785        2.00 %     4327022
# ..                      ...                ...           ...         ...
# 230              Montserrat               4993        0.06 %           3
# 231        Falkland Islands               3497        3.05 %         103
# 232                    Niue               1628        0.68 %          11
# 233                 Tokelau               1360        1.27 %          17
# 234                Holy See                801        0.25 %           2
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# ...

# %%
country.head()
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                   China         1440297825        0.39 %     5540090
# 1                   India         1382345085        0.99 %    13586631
# 2           United States          331341050        0.59 %     1937734
# 3               Indonesia          274021604        1.07 %     2898047
# 4                Pakistan          221612785        2.00 %     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              153          9388211       -348399.0        1.7       38
# 1              464          2973190       -532687.0        2.2       28
# 2               36          9147420        954806.0        1.8       38
# 3              151          1811570        -98955.0        2.3       30
# 4              287           770880       -233379.0        3.6       23
#
#   Urban Pop % World Share
# 0        61 %     18.47 %
# 1        35 %     17.70 %
# ...

# %%
country.columns
# Out:
# Index(['Country (or dependency)', 'Population (2020)', 'Yearly Change',
#        'Net Change', 'Density (P/Km²)', 'Land Area (Km²)', 'Migrants (net)',
#        'Fert. Rate', 'Med. Age', 'Urban Pop %', 'World Share'],
#       dtype='object')

# %%
country.corr()
# Out:
#                    Population (2020)  Net Change  Density (P/Km²)  \
# Population (2020)           1.000000    0.852329        -0.025433
# Net Change                  0.852329    1.000000        -0.033803
# Density (P/Km²)            -0.025433   -0.033803         1.000000
# Land Area (Km²)             0.455486    0.305668        -0.058766
# Migrants (net)             -0.267233   -0.302188         0.000155
#
#                    Land Area (Km²)  Migrants (net)
# Population (2020)         0.455486       -0.267233
# Net Change                0.305668       -0.302188
# Density (P/Km²)          -0.058766        0.000155
# Land Area (Km²)           1.000000        0.225414
# Migrants (net)            0.225414        1.000000

# %%
country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country (or dependency)  235 non-null    object
#  1   Population (2020)        235 non-null    int64
#  2   Yearly Change            235 non-null    object
#  3   Net Change               235 non-null    int64
#  4   Density (P/Km²)          235 non-null    int64
#  5   Land Area (Km²)          235 non-null    int64
#  6   Migrants (net)           201 non-null    float64
#  7   Fert. Rate               235 non-null    object
#  8   Med. Age                 235 non-null    object
#  9   Urban Pop %              235 non-null    object
#  10  World Share              235 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.3+ KB

# %%
country.describe()
# Out:
#        Population (2020)    Net Change  Density (P/Km²)  Land Area (Km²)  \
# count       2.350000e+02  2.350000e+02       235.000000     2.350000e+02
# mean        3.322744e+07  3.460878e+05       475.770213     5.535918e+05
# std         1.353034e+08  1.128260e+06      2331.285935     1.687796e+06
# min         8.010000e+02 -3.838400e+05         0.000000     0.000000e+00
# 25%         3.994905e+05  4.240000e+02        37.000000     2.545000e+03
# 50%         5.460109e+06  3.917000e+04        95.000000     7.724000e+04
# 75%         2.067170e+07  2.496600e+05       239.500000     4.038200e+05
# max         1.440298e+09  1.358663e+07     26337.000000     1.637687e+07
#
#        Migrants (net)
# count      201.000000
# mean         6.283582
# std     123291.887548
# min    -653249.000000
# 25%     -10047.000000
# 50%       -852.000000
# 75%       9741.000000
# max     954806.000000

# %%
country.isnull()
# Out:
#      Country (or dependency)  Population (2020)  Yearly Change  Net Change  \
# 0                      False              False          False       False
# 1                      False              False          False       False
# 2                      False              False          False       False
# 3                      False              False          False       False
# 4                      False              False          False       False
# ..                       ...                ...            ...         ...
# 230                    False              False          False       False
# 231                    False              False          False       False
# 232                    False              False          False       False
# 233                    False              False          False       False
# 234                    False              False          False       False
#
# ...

# %%
country.isnull().sum()
# Out:
# Country (or dependency)     0
# Population (2020)           0
# Yearly Change               0
# Net Change                  0
# Density (P/Km²)             0
# Land Area (Km²)             0
# Migrants (net)             34
# Fert. Rate                  0
# Med. Age                    0
# Urban Pop %                 0
# World Share                 0
# dtype: int64

# %%
country.isnull().any()
# Out:
# Country (or dependency)    False
# Population (2020)          False
# Yearly Change              False
# Net Change                 False
# Density (P/Km²)            False
# Land Area (Km²)            False
# Migrants (net)              True
# Fert. Rate                 False
# Med. Age                   False
# Urban Pop %                False
# World Share                False
# dtype: bool

# %%
country.dropna()
# Out:
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                     China         1440297825        0.39 %     5540090
# 1                     India         1382345085        0.99 %    13586631
# 2             United States          331341050        0.59 %     1937734
# 3                 Indonesia          274021604        1.07 %     2898047
# 4                  Pakistan          221612785        2.00 %     4327022
# ..                      ...                ...           ...         ...
# 196                   Aruba             106845        0.43 %         452
# 197                   Tonga             105901        1.15 %        1201
# 198     U.S. Virgin Islands             104398       -0.15 %        -153
# 199              Seychelles              98453        0.62 %         608
# 200     Antigua and Barbuda              98069        0.84 %         811
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# ...

# %%
country.dropna().sum()
# Out:
# Country (or dependency)    ChinaIndiaUnited StatesIndonesiaPakistanBrazil...
# Population (2020)                                                 7807315172
# Yearly Change              0.39 %0.99 %0.59 %1.07 %2.00 %0.72 %2.58 %1.01...
# Net Change                                                          81325079
# Density (P/Km²)                                                        72084
# Land Area (Km²)                                                    129663150
# Migrants (net)                                                        1263.0
# Fert. Rate                 1.72.21.82.33.61.75.42.11.82.11.44.32.63.32.16...
# Med. Age                   3828383023331828402948192625321732324640404247...
# Urban Pop %                61 %35 %83 %56 %35 %88 %52 %39 %74 %84 %92 %21...
# World Share                18.47 %17.70 %4.25 %3.51 %2.83 %2.73 %2.64 %2....
# dtype: object

# %%
sns.heatmap(country.isnull(),yticklabels=False,annot=True)
# Out:
# <AxesSubplot:>

# %%
country.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
country.plot()
# Out:
# <AxesSubplot:>

# %%
country.isna()
# Out:
#      Country (or dependency)  Population (2020)  Yearly Change  Net Change  \
# 0                      False              False          False       False
# 1                      False              False          False       False
# 2                      False              False          False       False
# 3                      False              False          False       False
# 4                      False              False          False       False
# ..                       ...                ...            ...         ...
# 230                    False              False          False       False
# 231                    False              False          False       False
# 232                    False              False          False       False
# 233                    False              False          False       False
# 234                    False              False          False       False
#
# ...

# %%
country.isna().sum()
# Out:
# Country (or dependency)     0
# Population (2020)           0
# Yearly Change               0
# Net Change                  0
# Density (P/Km²)             0
# Land Area (Km²)             0
# Migrants (net)             34
# Fert. Rate                  0
# Med. Age                    0
# Urban Pop %                 0
# World Share                 0
# dtype: int64

# %%
country.shape
# Out:
# (235, 11)
