# %%
import numpy as np 
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
df = pd.read_csv("NetFlix Latest TV shows and movies.csv")
df.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
df.shape
# Out:
# (7787, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   int64
#  10  genres        7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 730.2+ KB

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# genres             0
# description        0
# dtype: int64

# %%
df.loc[df['director'].isnull()]
# Out:
#      show_id     type                           title director  \
# 0         s1  TV Show                              3%      NaN
# 4      s1001  TV Show                  Blue Planet II      NaN
# 10     s1007  TV Show                             BNA      NaN
# 15     s1011  TV Show                   Bo on the Go!      NaN
# 17     s1013  TV Show  Bob Ross: Beauty Is Everywhere      NaN
# ...      ...      ...                             ...      ...
# 7777    s990  TV Show                      Blood Pact      NaN
# 7779    s992  TV Show                       Bloodline      NaN
# 7780    s993  TV Show                       Bloodride      NaN
# 7782    s995  TV Show                      Blown Away      NaN
# 7783    s996  TV Show                   Blue Exorcist      NaN
#
#                                                    cast         country  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# ...

# %%
df.loc[df['date_added'].isnull()]
# Out:
#      show_id     type                                        title director  \
# 1406   s2264  TV Show                                      Frasier      NaN
# 1433   s2289  TV Show                                      Friends      NaN
# 1730   s2556  TV Show                              Gunslinger Girl      NaN
# 1767    s259  TV Show  A Young Doctor's Notebook and Other Stories      NaN
# 2640   s3375  TV Show                                     Kikoriki      NaN
# 2771   s3493  TV Show                          La Familia P. Luche      NaN
# 3275   s3947  TV Show                                        Maron      NaN
# 4599   s5138  TV Show                                 Red vs. Blue      NaN
# 5001    s550  TV Show              Anthony Bourdain: Parts Unknown      NaN
# 5630   s6066  TV Show                 The Adventures of Figaro Pho      NaN
#
#                                                    cast         country  \
# ...

# %%
df1=df.dropna()

# %%
df1
# Out:
#      show_id   type                                      title  \
# 1        s10  Movie                                       1920
# 2       s100  Movie                                 3 Heroines
# 3      s1000  Movie  Blue Mountain State: The Rise of Thadland
# 5      s1002  Movie                                  Blue Ruin
# 6      s1003  Movie                                Blue Streak
# ...      ...    ...                                        ...
# 7778    s991  Movie                            Blood Will Tell
# 7781    s994  Movie                                       Blow
# 7784    s997  Movie                  Blue Is the Warmest Color
# 7785    s998  Movie                               Blue Jasmine
# 7786    s999  Movie                                   Blue Jay
#
#                         director  \
# 1                   Vikram Bhatt
# 2                 Iman Brotoseno
# 3                   Lev L. Spiro
# 5                Jeremy Saulnier
# 6                   Les Mayfield
# ...

# %%
df.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
df.tail()
# Out:
#      show_id     type                      title             director  \
# 7782    s995  TV Show                 Blown Away                  NaN
# 7783    s996  TV Show              Blue Exorcist                  NaN
# 7784    s997    Movie  Blue Is the Warmest Color  Abdellatif Kechiche
# 7785    s998    Movie               Blue Jasmine          Woody Allen
# 7786    s999    Movie                   Blue Jay         Alex Lehmann
#
#                                                    cast  \
# 7782                                                NaN
# 7783  Nobuhiko Okamoto, Jun Fukuyama, Kana Hanazawa,...
# 7784  Léa Seydoux, Adèle Exarchopoulos, Salim Kechio...
# 7785  Cate Blanchett, Sally Hawkins, Alec Baldwin, L...
# 7786           Sarah Paulson, Mark Duplass, Clu Gulager
#
#                      country date_added  release_year rating  duration  \
# 7782                  Canada  12-Jul-19          2019  TV-14         1
# ...

# %%
df["date_added"] = pd.to_datetime(df["date_added"])

# %%
df = df.rename(columns={"date_added": "date"})

# %%
df.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#         date  release_year rating  duration  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date          7777 non-null   datetime64[ns]
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   int64
#  10  genres        7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(9)
# memory usage: 730.2+ KB

# %%
df["rating"].describe()
# Out:
# count      7780
# unique       14
# top       TV-MA
# freq       2863
# Name: rating, dtype: object

# %%
df.describe()
# Out:
#        release_year     duration
# count   7787.000000  7787.000000
# mean    2013.932580    69.122769
# std        8.757395    50.950743
# min     1925.000000     1.000000
# 25%     2013.000000     2.000000
# 50%     2017.000000    88.000000
# 75%     2018.000000   106.000000
# max     2021.000000   312.000000

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date',
#        'release_year', 'rating', 'duration', 'genres', 'description'],
#       dtype='object')

# %%
df['cast'].unique()
# Out:
# array(['João Miguel, Bianca Comparato, Michel Gomes, Rodolfo Valente, Vaneza Oliveira, Rafael Lozano, Viviane Porto, Mel Fronckowiak, Sergio Mamberti, Zezé Motta, Celso Frateschi',
#        'Rajneesh Duggal, Adah Sharma, Indraneil Sengupta, Anjori Alagh, Rajendranath Zutshi, Vipin Sharma, Amin Hajee, Shri Vallabh Vyas',
#        'Reza Rahadian, Bunga Citra Lestari, Tara Basro, Chelsea Islan',
#        ...,
#        'Léa Seydoux, Adèle Exarchopoulos, Salim Kechiouche, Aurélien Recoing, Catherine Salée, Benjamin Siksou, Mona Walravens, Alma Jodorowsky, Jérémie Laheurte, Anne Loiret, Benoît Pilot, Sandor Funtek, Fanny Maurin',
#        'Cate Blanchett, Sally Hawkins, Alec Baldwin, Louis C.K., Bobby Cannavale, Andrew Dice Clay, Peter Sarsgaard, Michael Stuhlbarg, Tammy Blanchard, Max Casella, Alden Ehrenreich',
#        'Sarah Paulson, Mark Duplass, Clu Gulager'], dtype=object)

# %%
df['title'].unique()
# Out:
# array(['3%', '1920', '3 Heroines', ..., 'Blue Is the Warmest Color',
#        'Blue Jasmine', 'Blue Jay'], dtype=object)

# %%
sns.barplot(df['release_year'],df['genres'][:10])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='release_year', ylabel='genres'>

# %%
sns.barplot(df['duration'],df['genres'][:10])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='duration', ylabel='genres'>

# %%
sns.lineplot(df['release_year'], df['duration'])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='release_year', ylabel='duration'>

# %%
df['genres'][:15].value_counts().plot(kind='pie',)
# Out:
# <AxesSubplot:ylabel='genres'>

# %%
sns.pairplot(df)

# %%
numeric_cols = df.select_dtypes(include=[np.number])

# %%
numeric_cols
# Out:
#       release_year  duration
# 0             2020         4
# 1             2008       143
# 2             2016       124
# 3             2016        90
# 4             2017         1
# ...            ...       ...
# 7782          2019         1
# 7783          2017         2
# 7784          2013       180
# 7785          2013        98
# 7786          2016        81
#
# [7787 rows x 2 columns]

# %%
plt.figure(figsize=(13,9))
plt.hist(df["duration"], bins = 10)
plt.xlabel("duratioin")
plt.show()

# %%
#Checking average movie duration of directors
df.director.unique()
# Out:
# array([nan, 'Vikram Bhatt', 'Iman Brotoseno', ...,
#        'Miguel Cohan, Miguel Cohan', 'Abdellatif Kechiche', 'Woody Allen'],
#       dtype=object)

# %%
#calculating mean duration of moives of each directors
#for this purposes we are importing seaborn library
mean_duration = df.groupby("director")["duration"].mean()
mean_duration.plot()
plt.xlabel("Director")
plt.ylabel("Average Duration (minutes)")
plt.title("Relationship between Director and Average Duration")
plt.xticks(rotation=90)
plt.show()

# %%
#comparing duration and realease date
plt.figure(figsize=(13,8))
plt.scatter(df['release_year'], df['duration'])
plt.xlabel('Release Year')
plt.ylabel('Duration (minutes)')
plt.title('Scatter plot of Release Year against Duration')
plt.show()

# %%
#Use groupby() to analyze the average duration of shows by type
print(df.groupby("type")["duration"].mean())
# Out:
# type
# Movie      99.307978
# TV Show     1.775934
# Name: duration, dtype: float64

# %%
# Use a box plot to compare the duration of movies & shows by type
plt.figure(figsize=(13,9))
plt.boxplot([df[df["type"] == "Movie"]["duration"], df[df["type"] == "TV Show"]["duration"]], labels = ["Movies", "TV Shows"])
plt.ylabel("duration")
plt.show()

# %%
#Comparing and Visualising Movies and Their IMDB scores
#reading the data
df1=pd.read_csv("NetFlix Latest TV shows and movies.csv")

# %%
df1
# Out:
#      show_id     type                                      title  \
# 0         s1  TV Show                                         3%
# 1        s10    Movie                                       1920
# 2       s100    Movie                                 3 Heroines
# 3      s1000    Movie  Blue Mountain State: The Rise of Thadland
# 4      s1001  TV Show                             Blue Planet II
# ...      ...      ...                                        ...
# 7782    s995  TV Show                                 Blown Away
# 7783    s996  TV Show                              Blue Exorcist
# 7784    s997    Movie                  Blue Is the Warmest Color
# 7785    s998    Movie                               Blue Jasmine
# 7786    s999    Movie                                   Blue Jay
#
#                  director                                               cast  \
# 0                     NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...
